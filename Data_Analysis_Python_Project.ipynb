# %% [markdown]
# **Постановка задачи:**
#
# 1. Собрать данные о доходах и данные об аудитории сайта в единый отчёт.
# 2. Посчитать метрику ARPU по каждому устройству.
# 3. Найти модель устройства с наибольшим ARPU.
#
# В качестве источников информации инспользуется данные, полученные по API-запросу и данные CSV-файла
# .
#
#
#
# ---

# %% [markdown]
# Выполняю инсталяцию и импорт библиотек, которые могут понадобиться в ходе выполнения задач проекта.
#
# Для получения данных Яндекс.Метрики формирую словарь с параметрами запроса.
#
#
# ---

# %%
! pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)

# %%
import pandas as pd 
import numpy as np
import json 
import requests
from pprint import pprint

# %%
token = ' ' 
headers = {'Authorization': 'OAuth ' + token}

# %%
params = {'metrics': 'ym:s:users',
          'dimensions': 'ym:s:date, ym:s:deviceCategory, ym:s:mobilePhone, ym:s:mobilePhoneModel',
          'date1': '2019-05-01',
          'date2': '2019-05-31', 
          'limit': 100000,
          'ids': 30177909}
response = requests.get('https://api-metrika.yandex.net/stat/v1/data', params=params, headers=headers)
print (response.status_code)
metrika_data = response.json()
metrika_data
# Out:
# 200
# {'query': {'ids': [30177909],
#   'dimensions': ['ym:s:date',
#    'ym:s:deviceCategory',
#    'ym:s:mobilePhone',
#    'ym:s:mobilePhoneModel'],
#   'metrics': ['ym:s:users'],
#   'sort': ['-ym:s:users'],
#   'date1': '2019-05-01',
#   'date2': '2019-05-31',
#   'limit': 100000,
#   'offset': 1,
#   'group': 'Week',
#   'auto_group_size': '1',
#   'attr_name': '',
#   'quantile': '50',
#   'offline_window': '21',
#   'attribution': 'LastSign',
#   'currency': 'RUB',
#   'adfox_event_id': '0'},
#  'data': [{'dimensions': [{'name': '2019-05-20'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [105.0]},
#   {'dimensions': [{'name': '2019-05-16'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [94.0]},
#   {'dimensions': [{'name': '2019-05-22'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [94.0]},
#   {'dimensions': [{'name': '2019-05-23'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [92.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [91.0]},
#   {'dimensions': [{'name': '2019-05-14'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [87.0]},
#   {'dimensions': [{'name': '2019-05-15'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [83.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [83.0]},
#   {'dimensions': [{'name': '2019-05-21'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [81.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [76.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [75.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [75.0]},
#   {'dimensions': [{'name': '2019-05-17'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [74.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [74.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [74.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [74.0]},
#   {'dimensions': [{'name': '2019-05-24'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [71.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [62.0]},
#   {'dimensions': [{'name': '2019-05-26'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [46.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [45.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [44.0]},
#   {'dimensions': [{'name': '2019-05-25'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [44.0]},
#   {'dimensions': [{'name': '2019-05-19'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [43.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [42.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [42.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [39.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [38.0]},
#   {'dimensions': [{'name': '2019-05-18'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [38.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [36.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [23.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'desktop',
#      'icon_type': 'device',
#      'name': 'PC',
#      'id': 'desktop'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [21.0]},
#   {'dimensions': [{'name': '2019-05-16'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [10.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [7.0]},
#   {'dimensions': [{'name': '2019-05-15'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [6.0]},
#   {'dimensions': [{'name': '2019-05-18'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [6.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-14'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-19'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-22'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [5.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-19'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-21'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-25'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [4.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [3.0]},
#   {'dimensions': [{'name': '2019-05-20'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [3.0]},
#   {'dimensions': [{'name': '2019-05-23'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [3.0]},
#   {'dimensions': [{'name': '2019-05-24'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [3.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4', 'icon_id': '207'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '6', 'icon_type': 'mobile', 'name': 'Nokia', 'id': '6'},
#     {'icon_type': 'mobile', 'name': 'Lumia 625', 'icon_id': '6'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-16'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S7', 'icon_id': '7'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-17'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-26'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-26'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy A5', 'icon_id': '7'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 4A', 'icon_id': '207'}],
#    'metrics': [2.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-A600FN', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'JSN-L21', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi A1', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '400', 'icon_type': 'mobile', 'name': 'Meizu', 'id': '400'},
#     {'icon_type': 'mobile', 'name': '16th', 'icon_id': '400'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-01'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'COL-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'COR-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi Note 3', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-02'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-N960F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '18', 'icon_type': 'mobile', 'name': 'Lenovo', 'id': '18'},
#     {'icon_type': 'mobile', 'name': 'Lenovo A6010', 'icon_id': '18'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'HUAWEI CAN-L11', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-03'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'H4113', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '5', 'icon_type': 'mobile', 'name': 'Motorola', 'id': '5'},
#     {'icon_type': 'mobile', 'name': 'MotoG3', 'icon_id': '5'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-A600FN', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'STF-L09', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-04'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': 'mobile', 'name': 'M556', 'icon_id': '0'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-H840', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-K220', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi A2 Lite', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-05'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5A', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-A505FM', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-N960F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '17', 'icon_type': 'mobile', 'name': 'ASUS', 'id': '17'},
#     {'icon_type': 'mobile', 'name': 'ZC554KL', 'icon_id': '17'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '60', 'icon_type': 'mobile', 'name': 'ZTE', 'id': '60'},
#     {'icon_type': 'mobile', 'name': 'ZTE A2017', 'icon_id': '60'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'G3112', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 3S', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 4', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-06'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5A', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '5', 'icon_type': 'mobile', 'name': 'Motorola', 'id': '5'},
#     {'icon_type': 'mobile', 'name': 'moto e5 plus', 'icon_id': '5'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-K220', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '15', 'icon_type': 'mobile', 'name': 'Philips', 'id': '15'},
#     {'icon_type': 'mobile', 'name': 'Philips S398', 'icon_id': '15'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '60', 'icon_type': 'mobile', 'name': 'ZTE', 'id': '60'},
#     {'icon_type': 'mobile', 'name': 'ZTE T663', 'icon_id': '60'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'JSN-L21', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'D2403', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-07'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '522', 'icon_type': 'mobile', 'name': 'Tele2', 'id': '522'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '522'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy A3', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy J7', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S7', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'FRD-L19', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'TRT-LX1', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'VTR-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'D2533', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi A1', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-08'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': 'mobile', 'name': 'X527', 'icon_id': '0'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy A3', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S4', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-G960F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-G965F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '18', 'icon_type': 'mobile', 'name': 'Lenovo', 'id': '18'},
#     {'icon_type': 'mobile', 'name': 'Lenovo A5000', 'icon_id': '18'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'ANE-LX1', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'G3112', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-09'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPhone', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'CLT-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 4X', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '285', 'icon_type': 'mobile', 'name': 'OnePlus', 'id': '285'},
#     {'icon_type': 'mobile', 'name': 'ONEPLUS A5000', 'icon_id': '285'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy Tab A 9.7', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-10'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '450', 'icon_type': 'mobile', 'name': 'NVidia', 'id': '450'},
#     {'icon_type': 'mobile', 'name': 'SHIELD Tablet', 'icon_id': '450'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SAMSUNG SM-A505FN', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-A505FN', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-G965F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'Xperia Z1 Compact', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-11'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'MI 5s', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-G960U1', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '18', 'icon_type': 'mobile', 'name': 'Lenovo', 'id': '18'},
#     {'icon_type': 'mobile', 'name': 'Lenovo A6010', 'icon_id': '18'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'LLD-L31', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'PRA-TL10', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi A2 Lite', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-12'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '285', 'icon_type': 'mobile', 'name': 'OnePlus', 'id': '285'},
#     {'icon_type': 'mobile', 'name': 'ONEPLUS A6010', 'icon_id': '285'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy E5', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy Note II', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SAMSUNG SM-G935W8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-G965F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-H870DS', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 4X', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 5A', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4X', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '400', 'icon_type': 'mobile', 'name': 'Meizu', 'id': '400'},
#     {'icon_type': 'mobile', 'name': '16th', 'icon_id': '400'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-13'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '543',
#      'icon_type': 'mobile',
#      'name': 'Blackview',
#      'id': '543'},
#     {'icon_type': 'mobile', 'name': 'BV8000Pro', 'icon_id': '543'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-14'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
# ...
#     {'icon_type': 'mobile', 'name': 'ANE-LX1', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '83', 'icon_type': 'mobile', 'name': 'Sony', 'id': '83'},
#     {'icon_type': 'mobile', 'name': 'H4113', 'icon_id': '83'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'MI 6', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'POCOPHONE F1', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5A Prime', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 6 Pro', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-27'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': None, 'name': None, 'icon_id': None}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy A5', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S7', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-C5010', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-X240', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '18', 'icon_type': 'mobile', 'name': 'Lenovo', 'id': '18'},
#     {'icon_type': 'mobile', 'name': 'Lenovo A606', 'icon_id': '18'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '60', 'icon_type': 'mobile', 'name': 'ZTE', 'id': '60'},
#     {'icon_type': 'mobile', 'name': 'ZTE BLADE V0730', 'icon_id': '60'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'BND-L21', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'CRO-L22', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'HUAWEI G750-U10', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'LLD-L31', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'MI MAX', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-28'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 5', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy A5', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S5', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SAMSUNG SM-A505FN', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-N960F', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '9',
#      'icon_type': 'mobile',
#      'name': 'LG Electronics',
#      'id': '9'},
#     {'icon_type': 'mobile', 'name': 'LG-M700', 'icon_id': '9'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '17', 'icon_type': 'mobile', 'name': 'ASUS', 'id': '17'},
#     {'icon_type': 'mobile', 'name': 'ZC554KL', 'icon_id': '17'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'AUM-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'JAT-LX1', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'STF-L09', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'MI 8', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 3S', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-29'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': None, 'icon_type': None, 'name': None, 'id': None},
#     {'icon_type': 'mobile', 'name': '800P11B', 'icon_id': '0'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy S8', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'SM-A520W', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'CLT-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'COL-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'STF-L09', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'MI 8 SE', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Mi A1', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 5 Plus', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 5A', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 3', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4X', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '1', 'icon_type': 'mobile', 'name': 'Apple', 'id': '1'},
#     {'icon_type': 'mobile', 'name': 'iPad', 'icon_id': '1'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-30'},
#     {'icon_id': 'tablet',
#      'icon_type': 'device',
#      'name': 'Tablets',
#      'id': 'tablet'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy Tab 3 7.0 Lite', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '7', 'icon_type': 'mobile', 'name': 'Samsung', 'id': '7'},
#     {'icon_type': 'mobile', 'name': 'Galaxy J5', 'icon_id': '7'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'STF-L09', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '63', 'icon_type': 'mobile', 'name': 'Huawei', 'id': '63'},
#     {'icon_type': 'mobile', 'name': 'VTR-L29', 'icon_id': '63'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi 5 Plus', 'icon_id': '207'}],
#    'metrics': [1.0]},
#   {'dimensions': [{'name': '2019-05-31'},
#     {'icon_id': 'mobile',
#      'icon_type': 'device',
#      'name': 'Smartphones',
#      'id': 'mobile'},
#     {'icon_id': '207', 'icon_type': 'mobile', 'name': 'Xiaomi', 'id': '207'},
#     {'icon_type': 'mobile', 'name': 'Redmi Note 4', 'icon_id': '207'}],
#    'metrics': [1.0]}],
#  'total_rows': 320,
#  'total_rows_rounded': False,
#  'sampled': False,
#  'contains_sensitive_data': False,
#  'sample_share': 1.0,
#  'sample_size': 2711,
#  'sample_space': 2711,
#  'data_lag': 0,
#  'totals': [2033.0],
#  'min': [1.0],
#  'max': [105.0]}

# %% [markdown]
# Данные, полученные от API необходимо преобразовать в DataFrame.
#
# 1. Непосредственно статистические данные получаю по ключу 'data'.
# 2. Структурирую загруженные данные, избавившись от лишней информации и вывожу полученный DataFrame.
#
#
#
# ---

# %%
result = []

for data_item in metrika_data['data']:
    new_dict = {}
    for i,dimension in enumerate(data_item['dimensions']):
        new_dict[metrika_data['query']['dimensions'][i]] = dimension['name']
    for i,metric in enumerate(data_item['metrics']):
        new_dict[metrika_data['query']['metrics'][i]] = metric
    result.append(new_dict)
result
df = pd.DataFrame(result)
print(df)
# Out:
#       ym:s:date ym:s:deviceCategory ym:s:mobilePhone ym:s:mobilePhoneModel  \
# 0    2019-05-20                  PC             None                  None
# 1    2019-05-16                  PC             None                  None
# 2    2019-05-22                  PC             None                  None
# 3    2019-05-23                  PC             None                  None
# 4    2019-05-13                  PC             None                  None
# ..          ...                 ...              ...                   ...
# 315  2019-05-31         Smartphones          Samsung             Galaxy J5
# 316  2019-05-31         Smartphones           Huawei               STF-L09
# 317  2019-05-31         Smartphones           Huawei               VTR-L29
# 318  2019-05-31         Smartphones           Xiaomi          Redmi 5 Plus
# 319  2019-05-31         Smartphones           Xiaomi          Redmi Note 4
#
#      ym:s:users
# 0         105.0
# 1          94.0
# 2          94.0
# 3          92.0
# 4          91.0
# ..          ...
# 315         1.0
# 316         1.0
# 317         1.0
# 318         1.0
# 319         1.0
#
# [320 rows x 5 columns]

# %% [markdown]
# Проверяю информацию по заполняемости данными в полученном DataFrame.
#
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ym:s:date              320 non-null    object
#  1   ym:s:deviceCategory    320 non-null    object
#  2   ym:s:mobilePhone       280 non-null    object
#  3   ym:s:mobilePhoneModel  284 non-null    object
#  4   ym:s:users             320 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 12.6+ KB

# %% [markdown]
# Произвожу переименование колонок.
#
#
# ---

# %%
df.rename(columns={'ym:s:date': 'date', 'ym:s:deviceCategory' : 'deviceCategory', 'ym:s:mobilePhone' : 'mobilePhone', 'ym:s:mobilePhoneModel' : 'mobilePhoneModel', 'ym:s:users' : 'users'}, inplace=True)
df
# Out:
#            date deviceCategory mobilePhone mobilePhoneModel  users
# 0    2019-05-20             PC        None             None  105.0
# 1    2019-05-16             PC        None             None   94.0
# 2    2019-05-22             PC        None             None   94.0
# 3    2019-05-23             PC        None             None   92.0
# 4    2019-05-13             PC        None             None   91.0
# ..          ...            ...         ...              ...    ...
# 315  2019-05-31    Smartphones     Samsung        Galaxy J5    1.0
# 316  2019-05-31    Smartphones      Huawei          STF-L09    1.0
# 317  2019-05-31    Smartphones      Huawei          VTR-L29    1.0
# 318  2019-05-31    Smartphones      Xiaomi     Redmi 5 Plus    1.0
# 319  2019-05-31    Smartphones      Xiaomi     Redmi Note 4    1.0
#
# [320 rows x 5 columns]

# %% [markdown]
# Избавляюсь от None в ячейках DataFrame.
#
#
# ---

# %%
df_no_na = df.fillna(value = 'device')
df_no_na
# Out:
#            date deviceCategory mobilePhone mobilePhoneModel  users
# 0    2019-05-20             PC      device           device  105.0
# 1    2019-05-16             PC      device           device   94.0
# 2    2019-05-22             PC      device           device   94.0
# 3    2019-05-23             PC      device           device   92.0
# 4    2019-05-13             PC      device           device   91.0
# ..          ...            ...         ...              ...    ...
# 315  2019-05-31    Smartphones     Samsung        Galaxy J5    1.0
# 316  2019-05-31    Smartphones      Huawei          STF-L09    1.0
# 317  2019-05-31    Smartphones      Huawei          VTR-L29    1.0
# 318  2019-05-31    Smartphones      Xiaomi     Redmi 5 Plus    1.0
# 319  2019-05-31    Smartphones      Xiaomi     Redmi Note 4    1.0
#
# [320 rows x 5 columns]

# %% [markdown]
# Перед тем как совместить данные из отчёта Яндекс.Метрики и данные CSV-файла:
#
# 1. Группирую данные из отчёта Яндекс.Метрики по 'deviceCategory', 'mobilePhone', 'mobilePhoneModel' и суммирую количество пользователей для каждого типа устройств, посетивших сайт в течение месяца.
#
# 2. После группировки оставляю по условию задания только те строки получившейся таблицы, в которых оказалось трое и более пользователей.
#
#
#
# ---

# %%
grouped_df_copy = df_no_na.groupby(['deviceCategory', 'mobilePhone','mobilePhoneModel'])[['users']].sum()
df1 = grouped_df_copy[(grouped_df_copy['users'] >= 3)]
df1
# Out:
#                                                users
# deviceCategory mobilePhone mobilePhoneModel
# PC             device      device             1966.0
# Smartphones    ASUS        ZC554KL               3.0
#                Apple       iPhone              118.0
#                Huawei      AUM-L29               3.0
#                            CLT-L29               3.0
#                            COL-L29               3.0
#                            LLD-L31               4.0
#                            STF-L09               5.0
#                Meizu       16th                  3.0
#                Samsung     Galaxy A5             7.0
#                            Galaxy J7             3.0
#                            Galaxy S7             5.0
#                            Galaxy S8             6.0
#                            SAMSUNG SM-G935W8     3.0
#                            SM-G965F              4.0
#                            SM-N960F              4.0
#                Sony        G3112                 3.0
#                Xiaomi      MI 8                  3.0
#                            MI 8 SE               3.0
#                            Mi A1                 7.0
#                            Mi A2 Lite            3.0
#                            Redmi 4X              5.0
#                            Redmi 5 Plus          3.0
#                            Redmi 5A              3.0
#                            Redmi Note 3          3.0
#                            Redmi Note 4          7.0
#                            Redmi Note 4X         4.0
#                            Redmi Note 5          7.0
#                            Redmi Note 5A         3.0
#                device      device                5.0
# Tablets        Apple       iPad                 13.0

# %% [markdown]
# Получаю информацию об обработанном DataFrame, чтобы убедиться в готовности DataFrame для объединения с CSV-файлом и извленения финальных данных по исходному заданию к проекту
#
#
#
# ---

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 31 entries, ('PC', 'device', 'device') to ('Tablets', 'Apple', 'iPad')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   users   31 non-null     float64
# dtypes: float64(1)
# memory usage: 1.9+ KB

# %% [markdown]
# Загружаю CSV-файл в качестве дополнительного источника информации. И объеденяю его по общим колонкам с DataFrame, полученным по API-запросу ранее. Считаю значение ARPU для каждой строки. Получаю колонку с APPU и присоеденяю её к объёденённому DataFrame.
#
#
# ---

# %%
df2 = pd.read_csv('revenue_data.csv')
res = df2.merge(df1, on=['deviceCategory', 'mobilePhone', 'mobilePhoneModel'])
res_ARPU = res['revenue'] / res['users']
res['ARPU'] = res_ARPU
res
# Out:
#    deviceCategory mobilePhone   mobilePhoneModel    revenue  users      ARPU
# 0     Smartphones        ASUS            ZC554KL   1.130402    3.0  0.376801
# 1     Smartphones       Apple             iPhone   0.972879  118.0  0.008245
# 2     Smartphones      Huawei            AUM-L29   2.388569    3.0  0.796190
# 3     Smartphones      Huawei            CLT-L29   3.470900    3.0  1.156967
# 4     Smartphones      Huawei            COL-L29   2.758386    3.0  0.919462
# 5     Smartphones      Huawei            LLD-L31   5.220878    4.0  1.305220
# 6     Smartphones      Huawei            STF-L09   3.272568    5.0  0.654514
# 7     Smartphones       Meizu               16th   1.087090    3.0  0.362363
# 8     Smartphones     Samsung          Galaxy A5   5.060859    7.0  0.722980
# 9     Smartphones     Samsung          Galaxy J7   2.196402    3.0  0.732134
# 10    Smartphones     Samsung          Galaxy S7   3.940766    5.0  0.788153
# 11    Smartphones     Samsung          Galaxy S8   4.317546    6.0  0.719591
# 12    Smartphones     Samsung  SAMSUNG SM-G935W8   2.568895    3.0  0.856298
# 13    Smartphones     Samsung           SM-G965F   2.112749    4.0  0.528187
# 14    Smartphones     Samsung           SM-N960F   2.559977    4.0  0.639994
# 15    Smartphones        Sony              G3112   2.196634    3.0  0.732211
# 16    Smartphones      Xiaomi               MI 8   2.043934    3.0  0.681311
# 17    Smartphones      Xiaomi            MI 8 SE   1.287996    3.0  0.429332
# 18    Smartphones      Xiaomi              Mi A1   3.840106    7.0  0.548587
# 19    Smartphones      Xiaomi         Mi A2 Lite   1.513790    3.0  0.504597
# 20    Smartphones      Xiaomi           Redmi 4X   2.214447    5.0  0.442889
# 21    Smartphones      Xiaomi       Redmi 5 Plus   1.509677    3.0  0.503226
# 22    Smartphones      Xiaomi           Redmi 5A   2.124669    3.0  0.708223
# 23    Smartphones      Xiaomi       Redmi Note 3   1.535687    3.0  0.511896
# 24    Smartphones      Xiaomi       Redmi Note 4   4.313670    7.0  0.616239
# 25    Smartphones      Xiaomi      Redmi Note 4X   2.300131    4.0  0.575033
# 26    Smartphones      Xiaomi       Redmi Note 5   5.032546    7.0  0.718935
# 27    Smartphones      Xiaomi      Redmi Note 5A   4.240824    3.0  1.413608
# 28        Tablets       Apple               iPad  13.080439   13.0  1.006188

# %% [markdown]
# Финальный этап. Нахожу максимальное значение ARPU в соответствующей колонке и по индексу строки вывожу данные устройства с макимальным ARPU.
#
# **Поставленная задача выполнена.**
#
#
#
# ---

# %%
res['ARPU'].idxmax()
# Out:
# 27

# %%
max_ARPU = res.iloc[27]
max_ARPU
# Out:
# deviceCategory        Smartphones
# mobilePhone                Xiaomi
# mobilePhoneModel    Redmi Note 5A
# revenue                  4.240824
# users                         3.0
# ARPU                     1.413608
# Name: 27, dtype: object
